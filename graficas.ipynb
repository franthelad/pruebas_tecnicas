# %%
import spicy
import matplotlib.pyplot as plt

# %%
sample = spicy.stats.weibull_min.rvs(0.5, 2000, size=10000)

# %%
plt.hist(sample)
# Out:
# (array([9.624e+03, 2.630e+02, 7.300e+01, 2.700e+01, 9.000e+00, 2.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2000.00000003, 2010.48143769, 2020.96287535, 2031.444313  ,
#         2041.92575066, 2052.40718832, 2062.88862598, 2073.37006364,
#         2083.85150129, 2094.33293895, 2104.81437661]),
#  <BarContainer object of 10 artists>)
